# %% [markdown]
# #soumya

# %% [markdown]
# 1. what is the difference between a function and a method is python?
#   - this the answer

# %% [markdown]
# 2. second question
# - this is the answer

# %%
#question
,,,
this is answer
,,,
